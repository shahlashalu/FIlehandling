# %% [markdown]
# # **FILE HANDLING**

# %% [markdown]
# Create File
#
# Open File
#
# Read File
#
# Write File
#
# Closing

# %% [markdown]
# File Handling is an important part of any web application.
#
# Python has several functions for creating,reading,updating and deleting files.
#
# The key function for working with files in python is the open() function
#
# The open() function takes two parameters : filename and mode.
#
# There are four different methods(modes) for opening a file :

# %%
open('filename','mode')

# %% [markdown]
# **Mode Description**

# %% [markdown]
# "r" - Read - Default Value.Opens file for reading,error if file does not exist.
#
# "w" - This Mode opens file for Writing.If file does not exist , it creates a new file. If file exist it truncates the file.
#
# "x" - Creates a new file. If file already exist, the operation fails.
#
# "a" - Open file in the append mode. If file does not exist it creates a new file.
#
# "t" - This is default mode. It opens in text mode.
#
# "b" - It opens in binary mode.
#
# "+" - This will open a file for reading and writing(updating).

# %% [markdown]
# How to create a text file
#
#
# Create the file with open().
#
# f = open(filename,writemode)
#
#
# example,
#
# f = open("demo.txt","w+")
#
# w letter in our argument,which indicates write and will create a new file if it does not exist in library.
#
# + sign indicates both read and write.

# %%
f = open("demo01.txt","x")

# %%
f = open("/content/demo01.txt","a")
